# %% [markdown]
# #Задание

# %% [markdown]
# Используя модуль **datasets** библиотеки **sklearn**, загрузите базу вин (`.load_wine()`).
#
# Используя шаблон ноутбука, выполните загрузку, подготовку и предобработку данных. Обязательное условие: разделение данных на три выборки осуществляется по шаблону (изменять параметры подготовки данных запрещается)!
#
# Проведите серию экспериментов и добейтесь максимальной точности классификации на тестовой выборке выше 94%.
#
# ---
#
# С помощью метода `.summary()` зафиксируйте количество параметров созданной вами нейронной сети.

# %% [markdown]
# ##Шаблон ноутбука

# %%
# Последовательная модель НС
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization

# Утилиты для to_categorical()
from tensorflow.keras import utils

# Алгоритмы оптимизации для обучения модели
from tensorflow.keras.optimizers import Adam

# Библиотека для работы с массивами
import numpy as np

# Отрисовка графиков
import matplotlib.pyplot as plt

# Разделение данных на выборки
from sklearn.model_selection import train_test_split

# Для загрузки датасета
from sklearn.datasets import load_wine

# Отрисовка изображений в ноутбуке, а не в консоли или файле
# %matplotlib inline

# %% [markdown]
# ##Описание базы
#
# 1. Датасет состоит из набора данных о винах и их классах.
# 2. Данные по одному вину хранятся в numpy-массиве `x_data`: (`13` параметров).
# 3. В датасете `3` класса вин: `y_data`.
# 4. Количество примеров: `178`.

# %%
x_data = load_wine()['data']              # Загрузка набора данных о винах
y_data = load_wine()['target']            # Загрузка классов вин

print('Размерность x_data -', x_data.shape)
print('Размерность y_data -', y_data.shape)
print()

# Вывод примера данных
print('Данные по первому вину:',x_data[0])
print('Класс вина:',y_data[0])
# Out:
# Размерность x_data - (178, 13)
# Размерность y_data - (178,)
#
# Данные по первому вину: [1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#  2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]
# Класс вина: 0

# %% [markdown]
# ##Подготовка данных

# %%
# Перевод в one hot encoding
y_data = utils.to_categorical(y_data, 3)

# Разбиение наборов на общую и тестовую выборки
x_all, x_test, y_all, y_test = train_test_split(x_data,
                                                y_data,
                                                test_size=0.1,
                                                shuffle=True,
                                                random_state = 6)

# Разбиение общей выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(x_all,
                                                  y_all,
                                                  test_size=0.1,
                                                  shuffle=True,
                                                  random_state = 6)

print(x_train.shape)
print(y_train.shape)
print()
print(x_val.shape)
print(y_val.shape)
# Out:
# (144, 13)
# (144, 3)
#
# (16, 13)
# (16, 3)

# %% [markdown]
# ## Мое решение

# %%
# Создание модели
model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(3, activation='softmax')
])

# %%
# Компиляция и возврат модели
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Обучение сети
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=50,
                    batch_size=30,  # Увеличиваем размер пакета
                    verbose=1)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 46ms/step - loss: 25.4672 - accuracy: 0.3611 - val_loss: 18.1686 - val_accuracy: 0.3750
# Epoch 2/50
# 5/5 [==============================] - 0s 9ms/step - loss: 10.8343 - accuracy: 0.3889 - val_loss: 4.6387 - val_accuracy: 0.2500
# Epoch 3/50
# 5/5 [==============================] - 0s 9ms/step - loss: 5.8013 - accuracy: 0.3681 - val_loss: 5.6923 - val_accuracy: 0.5000
# Epoch 4/50
# 5/5 [==============================] - 0s 9ms/step - loss: 5.4116 - accuracy: 0.3958 - val_loss: 2.3451 - val_accuracy: 0.3750
# Epoch 5/50
# 5/5 [==============================] - 0s 9ms/step - loss: 2.3100 - accuracy: 0.4444 - val_loss: 2.6711 - val_accuracy: 0.4375
# Epoch 6/50
# 5/5 [==============================] - 0s 9ms/step - loss: 1.9283 - accuracy: 0.5000 - val_loss: 1.4667 - val_accuracy: 0.4375
# Epoch 7/50
# 5/5 [==============================] - 0s 9ms/step - loss: 1.8577 - accuracy: 0.4653 - val_loss: 0.4508 - val_accuracy: 0.7500
# Epoch 8/50
# 5/5 [==============================] - 0s 14ms/step - loss: 1.1527 - accuracy: 0.6667 - val_loss: 0.9078 - val_accuracy: 0.6250
# Epoch 9/50
# 5/5 [==============================] - 0s 9ms/step - loss: 1.0650 - accuracy: 0.5972 - val_loss: 0.7865 - val_accuracy: 0.5625
# Epoch 10/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9968 - accuracy: 0.5972 - val_loss: 0.5256 - val_accuracy: 0.8125
# Epoch 11/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7850 - accuracy: 0.6806 - val_loss: 0.4872 - val_accuracy: 0.6875
# Epoch 12/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7731 - accuracy: 0.6319 - val_loss: 0.5778 - val_accuracy: 0.7500
# Epoch 13/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8234 - accuracy: 0.6389 - val_loss: 0.4782 - val_accuracy: 0.7500
# Epoch 14/50
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7361 - accuracy: 0.6944 - val_loss: 0.5383 - val_accuracy: 0.8125
# Epoch 15/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7389 - accuracy: 0.7153 - val_loss: 0.4939 - val_accuracy: 0.7500
# Epoch 16/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6674 - accuracy: 0.7292 - val_loss: 0.6289 - val_accuracy: 0.6250
# Epoch 17/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7353 - accuracy: 0.6667 - val_loss: 0.5199 - val_accuracy: 0.7500
# Epoch 18/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.7750 - accuracy: 0.6944 - val_loss: 0.5791 - val_accuracy: 0.6875
# Epoch 19/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6710 - accuracy: 0.7014 - val_loss: 0.4591 - val_accuracy: 0.8750
# Epoch 20/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7055 - accuracy: 0.7222 - val_loss: 0.4090 - val_accuracy: 0.9375
# Epoch 21/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7206 - accuracy: 0.6458 - val_loss: 0.3941 - val_accuracy: 0.9375
# Epoch 22/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6352 - accuracy: 0.7153 - val_loss: 0.3925 - val_accuracy: 0.9375
# Epoch 23/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6007 - accuracy: 0.7500 - val_loss: 0.3875 - val_accuracy: 0.8750
# Epoch 24/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5884 - accuracy: 0.7847 - val_loss: 0.4464 - val_accuracy: 0.8750
# Epoch 25/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5961 - accuracy: 0.7361 - val_loss: 0.4195 - val_accuracy: 0.6875
# Epoch 26/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6233 - accuracy: 0.7708 - val_loss: 0.5398 - val_accuracy: 0.8125
# Epoch 27/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6522 - accuracy: 0.7014 - val_loss: 0.3981 - val_accuracy: 0.7500
# Epoch 28/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6300 - accuracy: 0.6944 - val_loss: 0.3855 - val_accuracy: 0.9375
# Epoch 29/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5795 - accuracy: 0.7639 - val_loss: 0.4197 - val_accuracy: 0.8750
# Epoch 30/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6022 - accuracy: 0.7153 - val_loss: 0.3672 - val_accuracy: 0.8750
# Epoch 31/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5709 - accuracy: 0.7569 - val_loss: 0.3827 - val_accuracy: 0.9375
# Epoch 32/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5460 - accuracy: 0.7500 - val_loss: 0.4242 - val_accuracy: 0.9375
# Epoch 33/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6390 - accuracy: 0.7222 - val_loss: 0.4186 - val_accuracy: 0.8750
# Epoch 34/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5952 - accuracy: 0.7708 - val_loss: 0.4161 - val_accuracy: 0.9375
# Epoch 35/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5276 - accuracy: 0.7847 - val_loss: 0.3341 - val_accuracy: 0.9375
# Epoch 36/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5595 - accuracy: 0.7847 - val_loss: 0.3267 - val_accuracy: 0.9375
# Epoch 37/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5435 - accuracy: 0.7708 - val_loss: 0.3349 - val_accuracy: 0.9375
# Epoch 38/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5297 - accuracy: 0.7917 - val_loss: 0.3126 - val_accuracy: 0.9375
# Epoch 39/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.5536 - accuracy: 0.7639 - val_loss: 0.3478 - val_accuracy: 0.8125
# Epoch 40/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.6196 - accuracy: 0.7014 - val_loss: 0.4948 - val_accuracy: 0.6875
# Epoch 41/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6109 - accuracy: 0.7361 - val_loss: 0.3857 - val_accuracy: 0.8125
# Epoch 42/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5307 - accuracy: 0.7569 - val_loss: 0.4075 - val_accuracy: 0.8750
# Epoch 43/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6852 - accuracy: 0.7222 - val_loss: 0.5475 - val_accuracy: 0.7500
# Epoch 44/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5269 - accuracy: 0.7500 - val_loss: 0.3563 - val_accuracy: 0.8125
# Epoch 45/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5261 - accuracy: 0.8194 - val_loss: 0.4036 - val_accuracy: 0.7500
# Epoch 46/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5212 - accuracy: 0.8056 - val_loss: 0.3750 - val_accuracy: 0.8750
# Epoch 47/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5258 - accuracy: 0.8681 - val_loss: 0.4257 - val_accuracy: 0.7500
# Epoch 48/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4908 - accuracy: 0.8125 - val_loss: 0.3376 - val_accuracy: 0.8750
# Epoch 49/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6358 - accuracy: 0.7292 - val_loss: 0.3006 - val_accuracy: 0.9375
# Epoch 50/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6328 - accuracy: 0.8125 - val_loss: 0.3099 - val_accuracy: 0.9375

# %%
# Краткая сводка архитектуры модели
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 64)                896
#
#  dense_55 (Dense)            (None, 32)                2080
#
#  dense_56 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 3075 (12.01 KB)
# Trainable params: 3075 (12.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Визуализация точности на обучающей выборке

plt.plot(history.history['accuracy'],
         label='Доля верных ответов на обучающем наборе')

# Визуализация точности на проверочной выборке
plt.plot(history.history['val_accuracy'],
         label='Доля верных ответов на проверочном наборе')

# Отрисовка подписей осей
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')

# Отрисовка легенды
plt.legend()

# Вывод графика
plt.show()

# %%
plt.plot(history.history['loss'],
         label='Ошибка на обучающем наборе')

plt.plot(history.history['val_loss'],
         label='Ошибка на проверочном наборе')

plt.xlabel('Эпоха обучения')
plt.ylabel('Ошибка')

plt.legend()

plt.show()

# %%
# Оценка модели на тестовой выборке
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')

# Вывод количества параметров модели
model.summary()
# Out:
# Test accuracy: 94.44%
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 64)                896
#
#  dense_55 (Dense)            (None, 32)                2080
#
#  dense_56 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 3075 (12.01 KB)
# Trainable params: 3075 (12.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
